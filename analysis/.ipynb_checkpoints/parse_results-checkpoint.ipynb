# %%
# In this notebook two type of experiments are considered
# - pure    -> experiments with one simultaneously running MPI task 
# - sharing -> experiments with two simultaneously running MPI tasks

# This experiments may be
# local  -> VMs connect between each other with local linux bridge 
# or
# remote -> VMs connect between each other with remote linux bridge

# Results for max 16 threads
RESULTS_PATH = {
    "pure": "../results/pure_NPB_local/cluster",
    "sharing": {
        "cluster_1": "../results/sharing_NPB_size_A_local/cluster_1",
        "cluster_2": "../results/sharing_NPB_size_A_local/cluster_2"
    }
}

# Results for max 32 threads
RESULTS_PATH = {
    "pure": "../../experiments_results/results/pure_NPB_local_32//cluster",
    "sharing": {
        "cluster_1": "../../experiments_results/results/sharing_NPB_size_A_local_32/cluster_1",
        "cluster_2": "../../experiments_results/results/sharing_NPB_size_A_local_32/cluster_2"
    }
}

# %%
# Pure experiments

import os
import json
import pandas as pd
from tabulate import tabulate
from collections import OrderedDict


def get_comp_time_pure(results_dir, tasks, sizes, procs, experiments_num):
    """This function parse results file and return computational statistics

    Args:
        results_dir (str): directory with result files.
            Each file has name with following pattern:
            <exec file name>_<task size>_<number of MPI procs>_e_<experiment seq num>.out
            
            Ex:
                lu.W.x_W_8_e_1.out

    Returns:
        dict: key   - task name 
              value - dict with
                  key   - task size
                  value - dict with
                      key   - number of proc
                      value - average computational time

    """
    
    if not os.path.isdir(results_dir):
        raise Exception("Cannot find directory ''%s'" % results_dir)
        
    results = {}
    
    for task in tasks:
        if task not in results:
            results[task] = OrderedDict()

        for size in sizes:
            if size not in results[task]:
                results[task][size] = OrderedDict()
            
            for proc in procs:
                if proc not in results[task][size]:
                    results[task][size][proc] = list()

                filename = "%s.%s.x_%s_%s" % (task, size, size, proc)
                for n in range(0, experiments_num):
                    full_path = os.path.join(results_dir, "%s_e_%d.out" % (filename, n))
                    if not os.path.isfile(full_path):
                        results[task][size][proc].append(float("nan"))
                    else:
                        with open(full_path, "r") as f:
                            line = f.readline()
                            while line != "":
                                if "Time in seconds" in line:
                                    results[task][size][proc].append(float(line.split('=')[1]))
                                    break
                                line = f.readline()

                if len(results[task][size][proc]) != 0:
                    results[task][size][proc] = sum(results[task][size][proc]) / float(len(results[task][size][proc]))
                else:
                    results[task][size][proc] = float("nan")

    return results

def print_comp_time_pure(comp_time, tasks):
    for task in tasks:
        df = pd.DataFrame(comp_time[task])
        print("Results for task '%s'" % (task))
        print(df)
        print('\n')

def get_resources_usage():
    # TODO
    pass


# ============================================================

# Read and print computational time
tasks = ["is", "ep", "cg", "lu", "ft"]
sizes = ["S", "W", "A", "B", "C", "D"]
# procs = [1, 2, 4, 8, 16]
procs = [1, 2, 4, 8, 16, 32]# NOTE! For 32 threads only
exp_num = 5

results_pure = get_comp_time_pure(RESULTS_PATH["pure"],
                                  tasks, sizes, procs, exp_num)

# print(json.dumps(results, sort_keys = True, indent = 4))
print_comp_time_pure(results_pure, tasks)


# Read and print information about resources usage
res_usage = get_resources_usage()
# Out:
# Results for task 'is'
#         S      W      A      B      C   D
# 1   0.000  0.070  0.978  3.854    NaN NaN
# 2   0.008  0.062  0.620  2.560    NaN NaN
# 4   0.010  0.040  0.368  1.432  6.150 NaN
# 8   0.010  0.028  0.256  0.888  3.846 NaN
# 16  0.014  0.038  0.206  0.754  2.922 NaN
# 32  0.868  0.942  1.148  1.996  4.446 NaN
#
#
# Results for task 'ep'
#         S      W       A       B        C         D
# 1   0.832  1.638  12.238  48.322  191.332  3013.194
# 2   0.466  0.860   6.342  24.860   98.136  1590.954
# 4   0.264  0.492   3.430  13.120   51.398   834.448
# 8   0.138  0.300   1.856   7.122   28.026   446.764
# 16  0.092  0.172   1.118   4.140   16.198   260.558
# 32  0.114  0.148   0.772   2.818   10.752   167.102
#
#
# Results for task 'cg'
#          S       W       A       B        C   D
# 1    0.042   0.254   0.992     NaN      NaN NaN
# 2    0.076   0.222   0.574  45.900      NaN NaN
# 4    0.080   0.168   0.410  32.182   95.502 NaN
# 8    0.122   0.190   0.346  12.198   46.342 NaN
# 16   0.206   0.260   0.400  16.872   40.888 NaN
# 32  11.118  11.934  12.232  71.194  112.358 NaN
#
#
# Results for task 'lu'
#         S       W       A        B        C        D
# 1   0.032   4.840  32.946  139.060      NaN      NaN
# 2   0.040   3.144  18.998   79.056  310.836      NaN
# 4   0.054   2.230  11.476   49.994  188.372      NaN
# 8   0.070   1.948   7.774   31.342  118.938      NaN
# 16  0.136   2.080   7.244   24.516   86.950      NaN
# 32    NaN  29.232  34.354   58.020  127.172  1596.08
#
#
# Results for task 'ft'
#         S      W      A       B       C   D
# 1   0.098  0.238    NaN     NaN     NaN NaN
# 2   0.076  0.162  2.640     NaN     NaN NaN
# 4   0.044  0.102  1.674     NaN     NaN NaN
# 8   0.030  0.070  1.088  12.794     NaN NaN
# 16  0.022  0.042  0.838   9.490     NaN NaN
# 32  0.240  0.262  3.106  18.130  49.802 NaN

# %%
# Sharing experiments
# We have checked yet sharing effect only on tasks with size A
# slowdown coefficient = time with sharing / pure time

# Names of result files
# pure
#     ep.B.x_B_16_e_0.out

# sharing 
#     ep.A.x_ep.A.x_8_4_e_0.out
#     ep.A.x_ep.A.x_8_16.out

from functools import reduce
from copy import deepcopy


def get_comp_time_sharing(dir1, dir2, tasks, procs, experiments_num):
    """This function parse results file and return computational statistics

    Args:
        dir1 and dir2 (str): directory with result files for cluster_1 and cluster_2
            Each file has name with following pattern:
            <exec file name 1>_<exec file name 2>_<number of MPI procs 1>_<number of MPI procs 2>_e_<experiment seq num>.out
            
            Ex:
                lu.A.x_lu.A.x_8_8_e_3.out

    Returns:
        dict: key   - tuple with two task names
              value - dict with
                  key   - tuple with np1, np2, where np is number of processes
                  value - tuple with two corresponding computational times

    """
    
    if not os.path.isdir(dir1):
        raise "Cannot find directory ''%s'" % dir1
        
    if not os.path.isdir(dir2):
        raise "Cannot find directory ''%s'" % dir2
        
    results = {}
    
    for i in range(0, len(tasks)):
        for j in range(i, len(tasks)):
            key_1 = tuple((tasks[i], tasks[j]))
            if key_1 not in results:
                results[key_1] = OrderedDict()

            for np1 in procs:
                for np2 in procs:
#                     print("RUN (%s, %s) (%s, %s)" % (tasks[i], tasks[j], np1, np2))
                    
#                     key_2 = str(np1) + ' ' + str(np2)
                    key_2 = tuple((np1, np2))
                    if key_2 not in results[key_1]:
                        results[key_1][key_2] = list()
                    
                    filename_1 = "%s.A.x_%s.A.x_%s_%s" % (tasks[i], tasks[j], np1, np2)
                    filename_2 = "%s.A.x_%s.A.x_%s_%s" % (tasks[j], tasks[i], np2, np1)
            
                    for n in range(0, experiments_num):
                        full_path_1 = os.path.join(dir1, "%s_e_%d.out" % (filename_1, n))
                        full_path_2 = os.path.join(dir2, "%s_e_%d.out" % (filename_2, n))
                        
                        t1 = float("nan")
                        t2 = float("nan")
                        
                        if os.path.isfile(full_path_1):
                            with open(full_path_1, "r") as f:
                                line = f.readline()
                                while line != "":
                                    if "Time in seconds" in line:
                                        t1 = float(line.split('=')[1])
                                        break
                                    line = f.readline()
                        
                        if os.path.isfile(full_path_2):
                            with open(full_path_2, "r") as f:
                                line = f.readline()
                                while line != "":
                                    if "Time in seconds" in line:
                                        t2 = float(line.split('=')[1])
                                        break
                                    line = f.readline()
                        
                        results[key_1][key_2].append([t1, t2])

                    if len(results[key_1][key_2]) != 0:
                        t1_sum = reduce(lambda a,b: a+b[0], results[key_1][key_2], 0)

                        t2_sum = reduce(lambda a,b: a+b[1], results[key_1][key_2], 0)
                        
                        results[key_1][key_2] = tuple((t1_sum / float(len(results[key_1][key_2])),
                                                       t2_sum / float(len(results[key_1][key_2]))))
                    else:
                        results[key_1][key_2] = tuple((float("nan"), float("nan")))
                    
    return results


def print_comp_time_sharing(comp_time, tasks):
    for i in range(0, len(tasks)):
        for j in range(i, len(tasks)):
            df = pd.DataFrame(comp_time[(tasks[i], tasks[j])])
            print("Results for pair (%s, %s)" % (tasks[i], tasks[j]))
            print(df)
            print('\n')

# ============================================================

# Read and print computational time
tasks = ["is", "ep", "cg", "lu", "ft"]
# procs = [4, 8, 16]
procs = [4, 8, 16, 32] # NOTE! For 32 thread only
exp_num = 1

results_sharing = get_comp_time_sharing(
            RESULTS_PATH["sharing"]["cluster_1"],
            RESULTS_PATH["sharing"]["cluster_2"],
            tasks, procs, exp_num)

print("Computational results for sharing experiments".upper())
print_comp_time_sharing(results_sharing, tasks)

# results for pure computation for all tasks with size A
print("Computational results for pure run for all tasks with size A".upper())
for task, task_res in results_pure.items():
    print("Results for '%s'" % task)
    df = pd.DataFrame(task_res)
    print(df['A'], '\n')
# Out:
# COMPUTATIONAL RESULTS FOR SHARING EXPERIMENTS
# Results for pair (is, is)
#      4                      8                       16                    \
#      4     8     16   32    4     8     16    32    4     8     16    32
# 0  0.63  0.57  0.49  1.8  0.84  0.48  0.37  2.13  0.59  0.29  0.33  2.19
# 1  0.39  0.35  0.30  1.6  0.44  0.46  0.30  1.92  0.40  0.42  0.30  2.36
#
#      32
#      4     8     16    32
# 0  2.13  1.44  1.66  2.00
# 1  0.41  0.30  0.26  2.48
#
#
# Results for pair (is, ep)
#      4                       8                       16                   \
#      4     8     16    32    4     8     16    32    4    8     16    32
# 0  0.40  0.47  0.49  1.59  0.35  0.34  0.35  1.26  0.25  0.3  0.88  1.00
# 1  3.73  2.03  1.26  1.14  3.76  2.09  1.30  1.17  3.89  2.1  1.36  1.54
#
#      32
#      4     8     16    32
# 0  1.87  1.86  1.33  1.34
# 1  4.53  2.75  1.39  1.41
#
#
# Results for pair (is, cg)
#      4                        8                        16                     \
#      4     8     16     32    4     8     16     32    4     8     16     32
# 0  0.43  0.55  0.54   3.23  0.43  0.38  0.40   2.63  0.24  0.33  1.65   3.45
# 1  0.49  0.53  0.61  12.45  0.52  0.61  0.77  11.90  0.62  0.66  2.27  13.05
#
#      32
#      4     8     16     32
# 0  1.32  1.35  1.83   3.39
# 1  0.62  0.63  2.05  13.91
#
#
# Results for pair (is, lu)
#       4                         8                         16              \
#       4     8     16     32     4     8     16     32     4     8     16
# 0   0.45  0.60  0.56   0.92   0.35  0.38  0.45   2.72   0.35  0.43  1.48
# 1  12.52  8.93  7.22  34.61  12.71  9.01  6.82  35.74  12.74  9.07  7.70
#
#              32
#       32     4      8     16     32
# 0   1.39   1.86   2.13  2.45   3.24
# 1  35.53  14.20  10.85  9.68  36.23
#
#
# Results for pair (is, ft)
#      4                       8                       16                    \
#      4     8     16    32    4     8     16    32    4     8     16    32
# 0  0.57  0.55  0.62  2.46  0.49  0.41  0.49  2.09  0.25  0.47  1.65  0.89
# 1  1.89  1.36  0.95  5.12  1.90  1.29  0.94  3.83  1.79  1.30  1.48  4.27
#
#      32
#      4     8     16    32
# 0  1.78  2.06  2.57  3.24
# 1  2.83  3.21  2.79  5.43
#
#
# Results for pair (ep, ep)
#      4                       8                       16                    \
#      4     8     16    32    4     8     16    32    4     8     16    32
# 0  3.86  4.17  4.01  4.74  2.33  2.51  2.26  2.87  1.28  1.29  1.52  2.09
# 1  3.94  2.45  1.29  1.04  3.88  2.51  1.31  1.30  4.02  2.26  1.49  1.59
#
#      32
#      4     8     16    32
# 0  1.68  1.32  1.68  2.07
# 1  4.58  2.80  2.35  1.87
#
#
# Results for pair (ep, cg)
#      4                        8                        16                     \
#      4     8     16     32    4     8     16     32    4     8     16     32
# 0  3.80  3.75  3.81   6.24  2.08  2.06  2.17   3.49  1.27  1.27  1.47   2.20
# 1  0.49  0.46  0.52  13.61  0.54  0.48  0.71  13.07  0.62  0.59  1.24  12.45
#
#      32
#      4     8     16     32
# 0  1.01  1.27  1.47   1.72
# 1  1.19  2.00  2.28  12.10
#
#
# Results for pair (ep, lu)
#       4                         8                         16              \
#       4     8     16     32     4     8     16     32     4     8     16
# 0   3.94  4.41  4.39   6.15   2.21  2.28  2.42   3.36   1.27  1.29  1.30
# 1  12.87  9.32  7.62  35.51  12.87  9.41  7.88  34.80  13.18  9.25  7.82
#
#              32
#       32     4      8     16     32
# 0   1.97   1.36   1.28  1.44   2.17
# 1  35.30  13.77  10.08  8.41  35.70
#
#
# Results for pair (ep, ft)
#      4                       8                      16                    \
#      4     8     16    32    4     8    16    32    4     8     16    32
# 0  3.93  3.87  4.03  5.35  2.21  2.46  2.3  3.42  1.26  1.33  1.43  2.01
# 1  1.86  1.32  0.93  5.58  1.89  1.56  1.0  4.35  2.00  1.49  1.70  4.27
#
#      32
#      4     8     16    32
# 0  1.18  1.30  1.49  1.82
# 1  2.42  2.33  2.51  4.70
#
#
# Results for pair (cg, cg)
#      4                        8                        16                     \
#      4     8     16     32    4     8     16     32    4     8     16     32
# 0  0.58  0.71  0.67   1.77  0.59  0.68  0.82   6.15  0.60  0.95  8.19  19.33
# 1  0.61  0.55  0.59  11.35  0.72  0.71  0.87  13.83  0.74  0.88  8.09  22.23
#
#       32
#       4      8      16     32
# 0  12.41  13.82  22.21  43.15
# 1   1.95   4.44  18.36  42.96
#
#
# Results for pair (cg, lu)
#       4                         8                         16               \
#       4     8     16     32     4     8     16     32     4     8      16
# 0   0.49  0.64  0.67   2.43   0.51  0.53  0.72   7.81   0.55  0.96   7.05
# 1  13.01  8.88  6.69  35.45  12.57  8.94  6.89  37.74  12.83  9.27  12.14
#
#              32
#       32     4      8      16     32
# 0  17.45  23.74  28.83  31.99  43.54
# 1  43.19  30.17  33.41  36.80  65.53
#
#
# Results for pair (cg, ft)
#      4                       8                       16                     \
#      4     8     16    32    4     8     16    32    4     8     16     32
# 0  0.54  0.71  0.84  2.24  0.38  0.66  0.90  4.03  0.60  0.99  4.41  18.06
# 1  1.83  1.30  0.93  4.23  1.83  1.33  1.03  4.58  1.87  1.44  3.32  14.76
#
#       32
#       4      8      16     32
# 0  14.66  14.41  15.46  26.21
# 1   6.19   5.76   8.97  18.35
#
#
# Results for pair (lu, lu)
#       4                          8                          16                \
#       4      8     16     32     4      8     16     32     4      8      16
# 0  14.51  15.63  15.3  32.61  10.95  12.78  13.7  45.64   8.42  11.43  29.29
# 1  14.89  11.66   8.6  44.72  14.71  12.82  11.4  51.28  15.70  13.76  29.79
#
#              32
#       32     4      8      16      32
# 0  49.89  44.55  49.56  58.80  102.35
# 1  58.48  33.00  44.32  49.81  103.58
#
#
# Results for pair (lu, ft)
#       4                          8                        16               \
#       4      8      16     32    4     8     16     32    4     8      16
# 0  13.16  13.37  13.54  21.80  9.63  9.56  9.62  21.75  7.70  7.69  10.24
# 1   2.00   1.46   0.95  11.01  2.44  1.66  1.13  13.03  2.57  1.96   3.28
#
#              32
#       32     4      8      16     32
# 0  20.92  37.42  38.58  40.56  51.29
# 1  12.94   4.41   5.68   9.97  18.35
#
#
# Results for pair (ft, ft)
#      4                       8                       16                    \
#      4     8     16    32    4     8     16    32    4     8     16    32
# 0  5.63  2.27  1.98  5.07  1.76  1.79  1.67  7.08  1.95  1.32  3.16  8.08
# 1  2.01  1.45  0.96  6.24  1.86  1.72  1.14  7.44  1.94  1.78  3.05  8.09
#
#      32
#      4     8     16     32
# 0  5.58  7.84  9.03  18.72
# 1  3.12  7.10  9.62  19.46
#
#
# COMPUTATIONAL RESULTS FOR PURE RUN FOR ALL TASKS WITH SIZE A
# Results for 'is'
# 1     0.978
# 2     0.620
# 4     0.368
# 8     0.256
# 16    0.206
# 32    1.148
# Name: A, dtype: float64
#
# Results for 'ep'
# 1     12.238
# 2      6.342
# 4      3.430
# 8      1.856
# 16     1.118
# 32     0.772
# Name: A, dtype: float64
#
# Results for 'ft'
# 1       NaN
# 2     2.640
# 4     1.674
# 8     1.088
# 16    0.838
# 32    3.106
# Name: A, dtype: float64
#
# Results for 'lu'
# 1     32.946
# 2     18.998
# 4     11.476
# 8      7.774
# 16     7.244
# 32    34.354
# Name: A, dtype: float64
#
# Results for 'cg'
# 1      0.992
# 2      0.574
# 4      0.410
# 8      0.346
# 16     0.400
# 32    12.232
# Name: A, dtype: float64

# %%
# Slowdown
# slowdown coefficient = time with sharing divided on pure time
print("Slowdown information".upper())

slowdown_info = deepcopy(results_sharing)
for tasks_pair, procs in slowdown_info.items():
    for procs_pair, t in procs.items():
        t1_p = results_pure[tasks_pair[0]]["A"][procs_pair[0]]
        t2_p = results_pure[tasks_pair[1]]["A"][procs_pair[1]]
        
        # print result only with sharing
        if (procs_pair[0] + procs_pair[1]) < 32:
            continue
        
        print("(%s,%s) (%2s,%2s) sharing: (%.3f,%.3f); pure: (%.3f,%.3f); slowdown: (%.3f,%.3f); rel slowdown: (%.3f)" % 
              (tasks_pair[0], tasks_pair[1], procs_pair[0], procs_pair[1], 
               t[0], t[1], t1_p, t2_p, t[0]/t1_p, t[1]/t2_p, float(max(t[0],t[1]))/(t1_p+t2_p)))
        
        slowdown_info[tasks_pair][procs_pair] = tuple((t[0]/t1_p , t[1]/t2_p))
# Out:
# SLOWDOWN INFORMATION
# (lu,ft) ( 4,32) sharing: (21.800,11.010); pure: (11.476,3.106); slowdown: (1.900,3.545); rel slowdown: (1.495)
# (lu,ft) ( 8,32) sharing: (21.750,13.030); pure: (7.774,3.106); slowdown: (2.798,4.195); rel slowdown: (1.999)
# (lu,ft) (16,16) sharing: (10.240,3.280); pure: (7.244,0.838); slowdown: (1.414,3.914); rel slowdown: (1.267)
# (lu,ft) (16,32) sharing: (20.920,12.940); pure: (7.244,3.106); slowdown: (2.888,4.166); rel slowdown: (2.021)
# (lu,ft) (32, 4) sharing: (37.420,4.410); pure: (34.354,1.674); slowdown: (1.089,2.634); rel slowdown: (1.039)
# (lu,ft) (32, 8) sharing: (38.580,5.680); pure: (34.354,1.088); slowdown: (1.123,5.221); rel slowdown: (1.089)
# (lu,ft) (32,16) sharing: (40.560,9.970); pure: (34.354,0.838); slowdown: (1.181,11.897); rel slowdown: (1.153)
# (lu,ft) (32,32) sharing: (51.290,18.350); pure: (34.354,3.106); slowdown: (1.493,5.908); rel slowdown: (1.369)
# (is,cg) ( 4,32) sharing: (3.230,12.450); pure: (0.368,12.232); slowdown: (8.777,1.018); rel slowdown: (0.988)
# (is,cg) ( 8,32) sharing: (2.630,11.900); pure: (0.256,12.232); slowdown: (10.273,0.973); rel slowdown: (0.953)
# (is,cg) (16,16) sharing: (1.650,2.270); pure: (0.206,0.400); slowdown: (8.010,5.675); rel slowdown: (3.746)
# (is,cg) (16,32) sharing: (3.450,13.050); pure: (0.206,12.232); slowdown: (16.748,1.067); rel slowdown: (1.049)
# (is,cg) (32, 4) sharing: (1.320,0.620); pure: (1.148,0.410); slowdown: (1.150,1.512); rel slowdown: (0.847)
# (is,cg) (32, 8) sharing: (1.350,0.630); pure: (1.148,0.346); slowdown: (1.176,1.821); rel slowdown: (0.904)
# (is,cg) (32,16) sharing: (1.830,2.050); pure: (1.148,0.400); slowdown: (1.594,5.125); rel slowdown: (1.324)
# (is,cg) (32,32) sharing: (3.390,13.910); pure: (1.148,12.232); slowdown: (2.953,1.137); rel slowdown: (1.040)
# (cg,lu) ( 4,32) sharing: (2.430,35.450); pure: (0.410,34.354); slowdown: (5.927,1.032); rel slowdown: (1.020)
# (cg,lu) ( 8,32) sharing: (7.810,37.740); pure: (0.346,34.354); slowdown: (22.572,1.099); rel slowdown: (1.088)
# (cg,lu) (16,16) sharing: (7.050,12.140); pure: (0.400,7.244); slowdown: (17.625,1.676); rel slowdown: (1.588)
# (cg,lu) (16,32) sharing: (17.450,43.190); pure: (0.400,34.354); slowdown: (43.625,1.257); rel slowdown: (1.243)
# (cg,lu) (32, 4) sharing: (23.740,30.170); pure: (12.232,11.476); slowdown: (1.941,2.629); rel slowdown: (1.273)
# (cg,lu) (32, 8) sharing: (28.830,33.410); pure: (12.232,7.774); slowdown: (2.357,4.298); rel slowdown: (1.670)
# (cg,lu) (32,16) sharing: (31.990,36.800); pure: (12.232,7.244); slowdown: (2.615,5.080); rel slowdown: (1.890)
# (cg,lu) (32,32) sharing: (43.540,65.530); pure: (12.232,34.354); slowdown: (3.560,1.907); rel slowdown: (1.407)
# (cg,cg) ( 4,32) sharing: (1.770,11.350); pure: (0.410,12.232); slowdown: (4.317,0.928); rel slowdown: (0.898)
# (cg,cg) ( 8,32) sharing: (6.150,13.830); pure: (0.346,12.232); slowdown: (17.775,1.131); rel slowdown: (1.100)
# (cg,cg) (16,16) sharing: (8.190,8.090); pure: (0.400,0.400); slowdown: (20.475,20.225); rel slowdown: (10.238)
# (cg,cg) (16,32) sharing: (19.330,22.230); pure: (0.400,12.232); slowdown: (48.325,1.817); rel slowdown: (1.760)
# (cg,cg) (32, 4) sharing: (12.410,1.950); pure: (12.232,0.410); slowdown: (1.015,4.756); rel slowdown: (0.982)
# (cg,cg) (32, 8) sharing: (13.820,4.440); pure: (12.232,0.346); slowdown: (1.130,12.832); rel slowdown: (1.099)
# (cg,cg) (32,16) sharing: (22.210,18.360); pure: (12.232,0.400); slowdown: (1.816,45.900); rel slowdown: (1.758)
# (cg,cg) (32,32) sharing: (43.150,42.960); pure: (12.232,12.232); slowdown: (3.528,3.512); rel slowdown: (1.764)
# (is,ft) ( 4,32) sharing: (2.460,5.120); pure: (0.368,3.106); slowdown: (6.685,1.648); rel slowdown: (1.474)
# (is,ft) ( 8,32) sharing: (2.090,3.830); pure: (0.256,3.106); slowdown: (8.164,1.233); rel slowdown: (1.139)
# (is,ft) (16,16) sharing: (1.650,1.480); pure: (0.206,0.838); slowdown: (8.010,1.766); rel slowdown: (1.580)
# (is,ft) (16,32) sharing: (0.890,4.270); pure: (0.206,3.106); slowdown: (4.320,1.375); rel slowdown: (1.289)
# (is,ft) (32, 4) sharing: (1.780,2.830); pure: (1.148,1.674); slowdown: (1.551,1.691); rel slowdown: (1.003)
# (is,ft) (32, 8) sharing: (2.060,3.210); pure: (1.148,1.088); slowdown: (1.794,2.950); rel slowdown: (1.436)
# (is,ft) (32,16) sharing: (2.570,2.790); pure: (1.148,0.838); slowdown: (2.239,3.329); rel slowdown: (1.405)
# (is,ft) (32,32) sharing: (3.240,5.430); pure: (1.148,3.106); slowdown: (2.822,1.748); rel slowdown: (1.276)
# (is,ep) ( 4,32) sharing: (1.590,1.140); pure: (0.368,0.772); slowdown: (4.321,1.477); rel slowdown: (1.395)
# (is,ep) ( 8,32) sharing: (1.260,1.170); pure: (0.256,0.772); slowdown: (4.922,1.516); rel slowdown: (1.226)
# (is,ep) (16,16) sharing: (0.880,1.360); pure: (0.206,1.118); slowdown: (4.272,1.216); rel slowdown: (1.027)
# (is,ep) (16,32) sharing: (1.000,1.540); pure: (0.206,0.772); slowdown: (4.854,1.995); rel slowdown: (1.575)
# (is,ep) (32, 4) sharing: (1.870,4.530); pure: (1.148,3.430); slowdown: (1.629,1.321); rel slowdown: (0.990)
# (is,ep) (32, 8) sharing: (1.860,2.750); pure: (1.148,1.856); slowdown: (1.620,1.482); rel slowdown: (0.915)
# (is,ep) (32,16) sharing: (1.330,1.390); pure: (1.148,1.118); slowdown: (1.159,1.243); rel slowdown: (0.613)
# (is,ep) (32,32) sharing: (1.340,1.410); pure: (1.148,0.772); slowdown: (1.167,1.826); rel slowdown: (0.734)
# (ep,lu) ( 4,32) sharing: (6.150,35.510); pure: (3.430,34.354); slowdown: (1.793,1.034); rel slowdown: (0.940)
# (ep,lu) ( 8,32) sharing: (3.360,34.800); pure: (1.856,34.354); slowdown: (1.810,1.013); rel slowdown: (0.961)
# (ep,lu) (16,16) sharing: (1.300,7.820); pure: (1.118,7.244); slowdown: (1.163,1.080); rel slowdown: (0.935)
# (ep,lu) (16,32) sharing: (1.970,35.300); pure: (1.118,34.354); slowdown: (1.762,1.028); rel slowdown: (0.995)
# (ep,lu) (32, 4) sharing: (1.360,13.770); pure: (0.772,11.476); slowdown: (1.762,1.200); rel slowdown: (1.124)
# (ep,lu) (32, 8) sharing: (1.280,10.080); pure: (0.772,7.774); slowdown: (1.658,1.297); rel slowdown: (1.179)
# (ep,lu) (32,16) sharing: (1.440,8.410); pure: (0.772,7.244); slowdown: (1.865,1.161); rel slowdown: (1.049)
# (ep,lu) (32,32) sharing: (2.170,35.700); pure: (0.772,34.354); slowdown: (2.811,1.039); rel slowdown: (1.016)
# (ep,ep) ( 4,32) sharing: (4.740,1.040); pure: (3.430,0.772); slowdown: (1.382,1.347); rel slowdown: (1.128)
# (ep,ep) ( 8,32) sharing: (2.870,1.300); pure: (1.856,0.772); slowdown: (1.546,1.684); rel slowdown: (1.092)
# (ep,ep) (16,16) sharing: (1.520,1.490); pure: (1.118,1.118); slowdown: (1.360,1.333); rel slowdown: (0.680)
# (ep,ep) (16,32) sharing: (2.090,1.590); pure: (1.118,0.772); slowdown: (1.869,2.060); rel slowdown: (1.106)
# (ep,ep) (32, 4) sharing: (1.680,4.580); pure: (0.772,3.430); slowdown: (2.176,1.335); rel slowdown: (1.090)
# (ep,ep) (32, 8) sharing: (1.320,2.800); pure: (0.772,1.856); slowdown: (1.710,1.509); rel slowdown: (1.065)
# (ep,ep) (32,16) sharing: (1.680,2.350); pure: (0.772,1.118); slowdown: (2.176,2.102); rel slowdown: (1.243)
# (ep,ep) (32,32) sharing: (2.070,1.870); pure: (0.772,0.772); slowdown: (2.681,2.422); rel slowdown: (1.341)
# (is,is) ( 4,32) sharing: (1.800,1.600); pure: (0.368,1.148); slowdown: (4.891,1.394); rel slowdown: (1.187)
# (is,is) ( 8,32) sharing: (2.130,1.920); pure: (0.256,1.148); slowdown: (8.320,1.672); rel slowdown: (1.517)
# (is,is) (16,16) sharing: (0.330,0.300); pure: (0.206,0.206); slowdown: (1.602,1.456); rel slowdown: (0.801)
# (is,is) (16,32) sharing: (2.190,2.360); pure: (0.206,1.148); slowdown: (10.631,2.056); rel slowdown: (1.743)
# (is,is) (32, 4) sharing: (2.130,0.410); pure: (1.148,0.368); slowdown: (1.855,1.114); rel slowdown: (1.405)
# (is,is) (32, 8) sharing: (1.440,0.300); pure: (1.148,0.256); slowdown: (1.254,1.172); rel slowdown: (1.026)
# (is,is) (32,16) sharing: (1.660,0.260); pure: (1.148,0.206); slowdown: (1.446,1.262); rel slowdown: (1.226)
# (is,is) (32,32) sharing: (2.000,2.480); pure: (1.148,1.148); slowdown: (1.742,2.160); rel slowdown: (1.080)
# (ep,cg) ( 4,32) sharing: (6.240,13.610); pure: (3.430,12.232); slowdown: (1.819,1.113); rel slowdown: (0.869)
# (ep,cg) ( 8,32) sharing: (3.490,13.070); pure: (1.856,12.232); slowdown: (1.880,1.069); rel slowdown: (0.928)
# (ep,cg) (16,16) sharing: (1.470,1.240); pure: (1.118,0.400); slowdown: (1.315,3.100); rel slowdown: (0.968)
# (ep,cg) (16,32) sharing: (2.200,12.450); pure: (1.118,12.232); slowdown: (1.968,1.018); rel slowdown: (0.933)
# (ep,cg) (32, 4) sharing: (1.010,1.190); pure: (0.772,0.410); slowdown: (1.308,2.902); rel slowdown: (1.007)
# (ep,cg) (32, 8) sharing: (1.270,2.000); pure: (0.772,0.346); slowdown: (1.645,5.780); rel slowdown: (1.789)
# (ep,cg) (32,16) sharing: (1.470,2.280); pure: (0.772,0.400); slowdown: (1.904,5.700); rel slowdown: (1.945)
# (ep,cg) (32,32) sharing: (1.720,12.100); pure: (0.772,12.232); slowdown: (2.228,0.989); rel slowdown: (0.930)
# (ep,ft) ( 4,32) sharing: (5.350,5.580); pure: (3.430,3.106); slowdown: (1.560,1.797); rel slowdown: (0.854)
# (ep,ft) ( 8,32) sharing: (3.420,4.350); pure: (1.856,3.106); slowdown: (1.843,1.401); rel slowdown: (0.877)
# (ep,ft) (16,16) sharing: (1.430,1.700); pure: (1.118,0.838); slowdown: (1.279,2.029); rel slowdown: (0.869)
# (ep,ft) (16,32) sharing: (2.010,4.270); pure: (1.118,3.106); slowdown: (1.798,1.375); rel slowdown: (1.011)
# (ep,ft) (32, 4) sharing: (1.180,2.420); pure: (0.772,1.674); slowdown: (1.528,1.446); rel slowdown: (0.989)
# (ep,ft) (32, 8) sharing: (1.300,2.330); pure: (0.772,1.088); slowdown: (1.684,2.142); rel slowdown: (1.253)
# (ep,ft) (32,16) sharing: (1.490,2.510); pure: (0.772,0.838); slowdown: (1.930,2.995); rel slowdown: (1.559)
# (ep,ft) (32,32) sharing: (1.820,4.700); pure: (0.772,3.106); slowdown: (2.358,1.513); rel slowdown: (1.212)
# (ft,ft) ( 4,32) sharing: (5.070,6.240); pure: (1.674,3.106); slowdown: (3.029,2.009); rel slowdown: (1.305)
# (ft,ft) ( 8,32) sharing: (7.080,7.440); pure: (1.088,3.106); slowdown: (6.507,2.395); rel slowdown: (1.774)
# (ft,ft) (16,16) sharing: (3.160,3.050); pure: (0.838,0.838); slowdown: (3.771,3.640); rel slowdown: (1.885)
# (ft,ft) (16,32) sharing: (8.080,8.090); pure: (0.838,3.106); slowdown: (9.642,2.605); rel slowdown: (2.051)
# (ft,ft) (32, 4) sharing: (5.580,3.120); pure: (3.106,1.674); slowdown: (1.797,1.864); rel slowdown: (1.167)
# (ft,ft) (32, 8) sharing: (7.840,7.100); pure: (3.106,1.088); slowdown: (2.524,6.526); rel slowdown: (1.869)
# (ft,ft) (32,16) sharing: (9.030,9.620); pure: (3.106,0.838); slowdown: (2.907,11.480); rel slowdown: (2.439)
# (ft,ft) (32,32) sharing: (18.720,19.460); pure: (3.106,3.106); slowdown: (6.027,6.265); rel slowdown: (3.133)
# (is,lu) ( 4,32) sharing: (0.920,34.610); pure: (0.368,34.354); slowdown: (2.500,1.007); rel slowdown: (0.997)
# (is,lu) ( 8,32) sharing: (2.720,35.740); pure: (0.256,34.354); slowdown: (10.625,1.040); rel slowdown: (1.033)
# (is,lu) (16,16) sharing: (1.480,7.700); pure: (0.206,7.244); slowdown: (7.184,1.063); rel slowdown: (1.034)
# (is,lu) (16,32) sharing: (1.390,35.530); pure: (0.206,34.354); slowdown: (6.748,1.034); rel slowdown: (1.028)
# (is,lu) (32, 4) sharing: (1.860,14.200); pure: (1.148,11.476); slowdown: (1.620,1.237); rel slowdown: (1.125)
# (is,lu) (32, 8) sharing: (2.130,10.850); pure: (1.148,7.774); slowdown: (1.855,1.396); rel slowdown: (1.216)
# (is,lu) (32,16) sharing: (2.450,9.680); pure: (1.148,7.244); slowdown: (2.134,1.336); rel slowdown: (1.153)
# (is,lu) (32,32) sharing: (3.240,36.230); pure: (1.148,34.354); slowdown: (2.822,1.055); rel slowdown: (1.021)
# (cg,ft) ( 4,32) sharing: (2.240,4.230); pure: (0.410,3.106); slowdown: (5.463,1.362); rel slowdown: (1.203)
# (cg,ft) ( 8,32) sharing: (4.030,4.580); pure: (0.346,3.106); slowdown: (11.647,1.475); rel slowdown: (1.327)
# (cg,ft) (16,16) sharing: (4.410,3.320); pure: (0.400,0.838); slowdown: (11.025,3.962); rel slowdown: (3.562)
# (cg,ft) (16,32) sharing: (18.060,14.760); pure: (0.400,3.106); slowdown: (45.150,4.752); rel slowdown: (5.151)
# (cg,ft) (32, 4) sharing: (14.660,6.190); pure: (12.232,1.674); slowdown: (1.198,3.698); rel slowdown: (1.054)
# (cg,ft) (32, 8) sharing: (14.410,5.760); pure: (12.232,1.088); slowdown: (1.178,5.294); rel slowdown: (1.082)
# (cg,ft) (32,16) sharing: (15.460,8.970); pure: (12.232,0.838); slowdown: (1.264,10.704); rel slowdown: (1.183)
# (cg,ft) (32,32) sharing: (26.210,18.350); pure: (12.232,3.106); slowdown: (2.143,5.908); rel slowdown: (1.709)
# (lu,lu) ( 4,32) sharing: (32.610,44.720); pure: (11.476,34.354); slowdown: (2.842,1.302); rel slowdown: (0.976)
# (lu,lu) ( 8,32) sharing: (45.640,51.280); pure: (7.774,34.354); slowdown: (5.871,1.493); rel slowdown: (1.217)
# (lu,lu) (16,16) sharing: (29.290,29.790); pure: (7.244,7.244); slowdown: (4.043,4.112); rel slowdown: (2.056)
# (lu,lu) (16,32) sharing: (49.890,58.480); pure: (7.244,34.354); slowdown: (6.887,1.702); rel slowdown: (1.406)
# (lu,lu) (32, 4) sharing: (44.550,33.000); pure: (34.354,11.476); slowdown: (1.297,2.876); rel slowdown: (0.972)
# (lu,lu) (32, 8) sharing: (49.560,44.320); pure: (34.354,7.774); slowdown: (1.443,5.701); rel slowdown: (1.176)
# (lu,lu) (32,16) sharing: (58.800,49.810); pure: (34.354,7.244); slowdown: (1.712,6.876); rel slowdown: (1.414)
# (lu,lu) (32,32) sharing: (102.350,103.580); pure: (34.354,34.354); slowdown: (2.979,3.015); rel slowdown: (1.508)

# %%
# Print slowdown info
print("Slowdown results for sharing experiments".upper())
print_comp_time_sharing(slowdown_info, tasks)

print(list(slowdown_info[('is', 'is')].keys()))
print(list(slowdown_info[('is', 'is')].values()))
# Out:
# SLOWDOWN RESULTS FOR SHARING EXPERIMENTS
# Results for pair (is, is)
#          4                                       8                       \
#          4         8         16        32        4         8         16
# 0  1.711957  1.548913  1.331522  4.891304  3.281250  1.875000  1.445312
# 1  1.059783  1.367187  1.456311  1.393728  1.195652  1.796875  1.456311
#
#                    16                                       32            \
#          32        4         8         16         32        4         8
# 0  8.320312  2.864078  1.407767  1.601942  10.631068  1.855401  1.254355
# 1  1.672474  1.086957  1.640625  1.456311   2.055749  1.114130  1.171875
#
#
#          16        32
# 0  1.445993  1.742160
# 1  1.262136  2.160279
#
#
# Results for pair (is, ep)
#          4                                       8                       \
#          4         8         16        32        4         8         16
# 0  1.086957  1.277174  1.331522  4.320652  1.367187  1.328125  1.367187
# 1  1.087464  1.093750  1.127013  1.476684  1.096210  1.126078  1.162791
#
#                    16                                     32            \
#          32        4         8         16        32       4         8
# 0  4.921875  1.213592  1.456311  4.271845  4.854369  1.62892  1.620209
# 1  1.515544  1.134111  1.131466  1.216458  1.994819  1.32070  1.481681
#
#
#          16        32
# 0  1.158537  1.167247
# 1  1.243292  1.826425
#
#
# Results for pair (is, cg)
#          4                                       8                     \
#          4         8         16        32        4         8       16
# 0  1.168478  1.494565  1.467391  8.777174  1.679688  1.484375  1.5625
# 1  1.195122  1.531792  1.525000  1.017822  1.268293  1.763006  1.9250
#
#                     16                                       32            \
#           32        4         8         16         32        4         8
# 0  10.273438  1.165049  1.601942  8.009709  16.747573  1.149826  1.175958
# 1   0.972858  1.512195  1.907514  5.675000   1.066874  1.512195  1.820809
#
#
#          16        32
# 0  1.594077  2.952962
# 1  5.125000  1.137181
#
#
# Results for pair (is, lu)
#          4                                       8                       \
#          4         8         16        32        4         8         16
# 0  1.222826  1.630435  1.521739  2.500000  1.367187  1.484375  1.757812
# 1  1.090972  1.148701  0.996687  1.007452  1.107529  1.158992  0.941469
#
#                     16                                      32            \
#           32        4         8         16        32        4         8
# 0  10.625000  1.699029  2.087379  7.184466  6.747573  1.620209  1.855401
# 1   1.040345  1.110143  1.166710  1.062949  1.034232  1.237365  1.395678
#
#
#          16        32
# 0  2.134146  2.822300
# 1  1.336278  1.054608
#
#
# Results for pair (is, ft)
#          4                                       8                       \
#          4         8         16        32        4         8         16
# 0  1.548913  1.494565  1.684783  6.684783  1.914062  1.601562  1.914062
# 1  1.129032  1.250000  1.133652  1.648422  1.135006  1.185662  1.121718
#
#                    16                                      32            \
#          32        4         8         16        32        4         8
# 0  8.164062  1.213592  2.281553  8.009709  4.320388  1.550523  1.794425
# 1  1.233097  1.069295  1.194853  1.766110  1.374759  1.690562  2.950368
#
#
#          16        32
# 0  2.238676  2.822300
# 1  3.329356  1.748229
#
#
# Results for pair (ep, ep)
#          4                                       8                       \
#          4         8         16        32        4         8         16
# 0  1.125364  1.215743  1.169096  1.381924  1.255388  1.352371  1.217672
# 1  1.148688  1.320043  1.153846  1.347150  1.131195  1.352371  1.171735
#
#                    16                                      32            \
#          32        4         8         16        32        4         8
# 0  1.546336  1.144902  1.153846  1.359571  1.869410  2.176166  1.709845
# 1  1.683938  1.172012  1.217672  1.332737  2.059585  1.335277  1.508621
#
#
#          16        32
# 0  2.176166  2.681347
# 1  2.101968  2.422280
#
#
# Results for pair (ep, cg)
#          4                                       8                       \
#          4         8         16        32        4         8         16
# 0  1.107872  1.093294  1.110787  1.819242  1.120690  1.109914  1.169181
# 1  1.195122  1.329480  1.300000  1.112655  1.317073  1.387283  1.775000
#
#                    16                                      32            \
#          32        4         8         16        32        4         8
# 0  1.880388  1.135957  1.135957  1.314848  1.967800  1.308290  1.645078
# 1  1.068509  1.512195  1.705202  3.100000  1.017822  2.902439  5.780347
#
#
#          16        32
# 0  1.904145  2.227979
# 1  5.700000  0.989209
#
#
# Results for pair (ep, lu)
#          4                                       8                       \
#          4         8         16        32        4         8         16
# 0  1.148688  1.285714  1.279883  1.793003  1.190733  1.228448  1.303879
# 1  1.121471  1.198868  1.051905  1.033650  1.121471  1.210445  1.087797
#
#                    16                                      32            \
#          32        4         8         16        32        4         8
# 0  1.810345  1.135957  1.153846  1.162791  1.762075  1.761658  1.658031
# 1  1.012982  1.148484  1.189864  1.079514  1.027537  1.199895  1.296630
#
#
#          16        32
# 0  1.865285  2.810881
# 1  1.160961  1.039180
#
#
# Results for pair (ep, ft)
#          4                                       8                       \
#          4         8         16        32        4         8         16
# 0  1.145773  1.128280  1.174927  1.559767  1.190733  1.325431  1.239224
# 1  1.111111  1.213235  1.109785  1.796523  1.129032  1.433824  1.193317
#
#                    16                                     32            \
#          32        4         8        16        32        4         8
# 0  1.842672  1.127013  1.189624  1.27907  1.797853  1.528497  1.683938
# 1  1.400515  1.194743  1.369485  2.02864  1.374759  1.445639  2.141544
#
#
#          16        32
# 0  1.930052  2.357513
# 1  2.995227  1.513200
#
#
# Results for pair (cg, cg)
#          4                                       8                       \
#          4         8         16        32        4         8         16
# 0  1.414634  1.731707  1.634146  4.317073  1.705202  1.965318  2.369942
# 1  1.487805  1.589595  1.475000  0.927894  1.756098  2.052023  2.175000
#
#                     16                                     32             \
#           32        4         8       16         32        4          8
# 0  17.774566  1.500000  2.375000  20.475  48.325000  1.014552   1.129823
# 1   1.130641  1.804878  2.543353  20.225   1.817364  4.756098  12.832370
#
#
#           16        32
# 0   1.815729  3.527632
# 1  45.900000  3.512099
#
#
# Results for pair (cg, lu)
#          4                                       8                       \
#          4         8         16        32        4         8         16
# 0  1.195122  1.560976  1.634146  5.926829  1.473988  1.531792  2.080925
# 1  1.133670  1.142269  0.923523  1.031903  1.095329  1.149987  0.951132
#
#                     16                                       32            \
#           32        4         8         16         32        4         8
# 0  22.572254  1.375000  2.400000  17.62500  43.625000  1.940811  2.356933
# 1   1.098562  1.117985  1.192436   1.67587   1.257204  2.628965  4.297659
#
#
#          16        32
# 0  2.615271  3.559516
# 1  5.080066  1.907493
#
#
# Results for pair (cg, ft)
#          4                                       8                       \
#          4         8         16        32        4         8         16
# 0  1.317073  1.731707  2.048780  5.463415  1.098266  1.907514  2.601156
# 1  1.093190  1.194853  1.109785  1.361880  1.093190  1.222426  1.229117
#
#                     16                                        32            \
#           32        4         8          16         32        4         8
# 0  11.647399  1.500000  2.475000  11.025000  45.150000  1.198496  1.178058
# 1   1.474565  1.117085  1.323529   3.961814   4.752093  3.697730  5.294118
#
#
#           16       32
# 0   1.263898  2.14274
# 1  10.704057  5.90792
#
#
# Results for pair (lu, lu)
#          4                                       8                       \
#          4         8         16        32        4         8         16
# 0  1.264378  1.361973  1.333217  2.841582  1.408541  1.643941  1.762285
# 1  1.297490  1.499871  1.187189  1.301741  1.281806  1.649087  1.573716
#
#                    16                                      32            \
#          32        4         8         16        32        4         8
# 0  5.870852  1.162341  1.577858  4.043346  6.887079  1.296792  1.442627
# 1  1.492694  1.368072  1.770003  4.112369  1.702276  2.875566  5.701055
#
#
#          16        32
# 0  1.711591  2.979275
# 1  6.876035  3.015078
#
#
# Results for pair (lu, ft)
#          4                                       8                       \
#          4         8         16        32        4         8         16
# 0  1.146741  1.165040  1.179854  1.899617  1.238745  1.229740  1.237458
# 1  1.194743  1.341912  1.133652  3.544752  1.457587  1.525735  1.348449
#
#                    16                                      32            \
#          32        4         8         16        32        4         8
# 0  2.797787  1.062949  1.061568  1.413584  2.887907  1.089247  1.123013
# 1  4.195106  1.535245  1.801471  3.914081  4.166130  2.634409  5.220588
#
#
#           16        32
# 0   1.180649  1.492985
# 1  11.897375  5.907920
#
#
# Results for pair (ft, ft)
#          4                                       8                       \
#          4         8         16        32        4         8         16
# 0  3.363202  1.356033  1.182796  3.028674  1.617647  1.645221  1.534926
# 1  1.200717  1.332721  1.145585  2.009015  1.111111  1.580882  1.360382
#
#                    16                                      32            \
#          32        4         8         16        32        4         8
# 0  6.507353  2.326969  1.575179  3.770883  9.642005  1.796523  2.524147
# 1  2.395364  1.158901  1.636029  3.639618  2.604636  1.863799  6.525735
#
#
#           16        32
# 0   2.907276  6.027044
# 1  11.479714  6.265293
#
#
# [(4, 4), (4, 8), (4, 16), (4, 32), (8, 4), (8, 8), (8, 16), (8, 32), (16, 4), (16, 8), (16, 16), (16, 32), (32, 4), (32, 8), (32, 16), (32, 32)]
# [(1.7119565217391304, 1.0597826086956523), (1.5489130434782608, 1.3671874999999998), (1.3315217391304348, 1.4563106796116503), (4.891304347826087, 1.3937282229965156), (3.28125, 1.1956521739130435), (1.875, 1.796875), (1.4453125, 1.4563106796116503), (8.3203125, 1.6724738675958186), (2.8640776699029122, 1.0869565217391306), (1.407766990291262, 1.640625), (1.6019417475728155, 1.4563106796116503), (10.631067961165048, 2.05574912891986), (1.8554006968641112, 1.1141304347826086), (1.254355400696864, 1.171875), (1.4459930313588847, 1.262135922330097), (1.7421602787456445, 2.160278745644599)]

# %%
# Draw slowdown info

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
# %matplotlib inline


tasks = ["is", "ep", "cg", "lu", "ft"]
colors = {"is": "red", "ep": "blue", "cg": "orange", "lu": "black", "ft": "cyan"}
markers = {"is": ".", "ep": "_", "cg": "+", "lu": "x", "ft": "."}

# Figure configuration
fig = plt.figure(figsize=(12,30), dpi=300)
ax = fig.add_subplot(111)
plt.title('NPB MPI tasks slowdown, size A', fontsize=16)

# Draw
for tasks_pair, procs in slowdown_info.items():
    n = 0
    for procs_pair, sl in procs.items():
        task1 = tasks_pair[0]
        task2 = tasks_pair[1]
        sl1 = sl[0]
        sl2 = sl[1]
        
        ax.plot(n, sl1, color=colors[task1], marker=markers[task1])
        ax.plot(n, sl2, color=colors[task2], marker=markers[task2])
        
        n += 1

# Draw slowdown lines with factor 1 and 2
null_slowdown_x = np.linspace(0, len(slowdown_info[('is', 'is')].keys())-1, num=2)
null_slowdown_y = np.zeros(2)
ax.plot(null_slowdown_x, null_slowdown_y+1, color="red", linestyle=":")

ax.plot(null_slowdown_x, null_slowdown_y+2, color="red", linestyle=":")

# Axes configuration
ax.set_xticks(np.arange(len(slowdown_info[('is', 'is')].keys())))
ax.set_xticklabels(list(slowdown_info[('is', 'is')].keys()))
ax.set_xlabel("(np1, np2)")
ax.set_ylabel("Slowdown (share / pure) [seconds]")


# Grid configuration
stepsize = 0.2
start, end = ax.get_ylim()
ax.yaxis.set_ticks(np.arange(0, end, stepsize))

ax.set_axisbelow(True)
ax.grid(which='both')
ax.grid(which='major', alpha=0.5)

# Form legend
legend_elements = []
for task in tasks:
    legend_elements.append(
        Line2D([], [], marker=markers[task], color=colors[task], linestyle='None', label=task, markersize=10))

# Show figure
ax.legend(handles=legend_elements)
plt.tight_layout()
plt.show()
fig.savefig('./slowdown_size_A.png', fmt='png')
plt.close(fig)
# plt.gcf().clear()

# %%
# Draw slowdown info
# Marked tasks whose slowdown coefficient in [1,2]
# If both tasks in pair have slowdown coefficient more than 2 -> red
# If one tasks in pair have slowdown coefficient more than 2, another less than 2 -> yellow
# If both tasks in pair have slowdown coefficient less than 2 -> green

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
# %matplotlib inline


tasks = ["is", "ep", "cg", "lu", "ft"]
colors = {"is": "red", "ep": "blue", "cg": "orange", "lu": "black", "ft": "cyan"}
markers = {"is": ".", "ep": "_", "cg": "+", "lu": "x", "ft": "."}

# Figure configuration
fig = plt.figure(figsize=(12,30), dpi=300)
ax = fig.add_subplot(111)
plt.title('NPB MPI tasks slowdown by groups, size A', fontsize=16)

# Draw
# X_DOTS = [2, 5, 6, 7, 8] # index int list [(4,4), (4,8), ..., (16,16)]
X_DOTS = [3, 7, 11, 12, 13, 14, 15] # NOTE! For 32 threads only

green = 0
red = 0
yellow = 0

for tasks_pair, procs in slowdown_info.items():
    n = -1
    for procs_pair, sl in procs.items():
        n += 1
        if (n not in X_DOTS):
            continue
        
        task1 = tasks_pair[0]
        task2 = tasks_pair[1]
        sl1 = sl[0]
        sl2 = sl[1]
        
        color = "black"
        if sl1 < 2 and sl2 < 2:
            color = "green"
            green += 1
        elif sl1 >= 2 and sl2 >= 2:
            color = "red"
            red += 1
        else:
            color = "yellow"
            yellow += 1
            
        ax.plot(X_DOTS.index(n), sl1, color=color, marker=markers[task1])
        ax.plot(X_DOTS.index(n), sl2, color=color, marker=markers[task2])

# Draw slowdown lines with factor 1 and 2
PROCS_PAIR = list(slowdown_info[('is', 'is')].keys())
null_slowdown_x = np.linspace(0, len(X_DOTS)-1, num=2)
null_slowdown_y = np.zeros(2)
ax.plot(null_slowdown_x, null_slowdown_y+1, color="red", linestyle=":")

ax.plot(null_slowdown_x, null_slowdown_y+2, color="red", linestyle=":")

# Axes configuration
ax.set_xticks(np.arange(len(X_DOTS)))
ax.set_xticklabels([PROCS_PAIR[i] for i in X_DOTS])
ax.set_xlabel("(np1, np2)")
ax.set_ylabel("Slowdown (share / pure) [seconds]")


# Grid configuration
stepsize = 0.2
start, end = ax.get_ylim()
ax.yaxis.set_ticks(np.arange(0, end, stepsize))

ax.set_axisbelow(True)
ax.grid(which='both')
ax.grid(which='major', alpha=0.5)

# Form legend
legend_elements = []
for task in tasks:
    legend_elements.append(
        Line2D([], [], marker=markers[task], color="black", linestyle='None', label=task, markersize=10))

legend_elements.append(
        Line2D([0], [0], color="green", linestyle='-', label="Both tasks less 2, %d pairs" % green))
legend_elements.append(
        Line2D([0], [0], color="red", linestyle='-', label="Both tasks more 2, %d pairs" % red))
legend_elements.append(
        Line2D([0], [0], color="yellow", linestyle='-', label="One more 2 another less 2, %d pairs" % yellow))

# Show figure
ax.legend(handles=legend_elements)
plt.tight_layout()
plt.show()
fig.savefig('./slowdown_size_A_groups_%s.png' % str('_'.join(map(str, X_DOTS))), fmt='png')
plt.close(fig)
# plt.gcf().clear()

# %%
# Divide tasks in six groups, see comments in above cell

# GROUP 1: [0,1] [0,1]
# GROUP 2: [1,2] [1,2]
# GROUP 3: [2,inf] [2,inf]
# GROUP 4: [0,1] [1,2]
# GROUP 5: [0,1] [2,inf]
# GROUP 6: [1,2] [2,inf]

print("Divide tasks in six groups".upper())

slowdown_groups = OrderedDict([
    ("GROUP 1: [0,1) [0,1)", []),
    ("GROUP 2: [1,2) [1,2)", []),
    ("GROUP 3: [2,inf) [2,inf)", []),
    ("GROUP 4: [0,1] [1,2] or [1,2] [0,1]", []),
    ("GROUP 5: [0,1] [2,inf] or [2,inf] [0,1]", []),
    ("GROUP 6: [1,2] [2,inf] or [2,inf] [1,2]", [])
])


sum_group_sizes = 0

procs_required = [16]
# procs_limit = 16 # number of processes without sharing
procs_limit = 32 # NOTE! For 32 thread only

for tasks_pair, procs in slowdown_info.items():
    for procs_pair, t in procs.items():
#         print("(%s,%s) (%2s,%2s) ; slowdown: (%f,%f)" % 
#               (tasks_pair[0], tasks_pair[1], procs_pair[0], procs_pair[1], t[0], t[1]))

        if (procs_pair[0] + procs_pair[1]) <= procs_limit:
            continue
#         if not (procs_pair[0] in procs_required or procs_pair[1] in procs_required):
#             continue

        if t[0] >= 0 and t[0] < 1 and t[1] >= 0 and t[1] < 1:
            slowdown_groups["GROUP 1: [0,1) [0,1)"].append((tasks_pair, procs_pair, t))
            sum_group_sizes += 1

        if t[0] >= 1 and t[0] < 2 and t[1] >= 1 and t[1] < 2:
            slowdown_groups["GROUP 2: [1,2) [1,2)"].append((tasks_pair, procs_pair, t))
            sum_group_sizes += 1
            
        if t[0] >= 2 and t[1] >= 2:
            slowdown_groups["GROUP 3: [2,inf) [2,inf)"].append((tasks_pair, procs_pair, t))
            sum_group_sizes += 1
            
        if (t[0] >= 0 and t[0] <= 1 and t[1] >= 1 and t[1] <= 2) or \
           (t[1] >= 0 and t[1] <= 1 and t[0] >= 1 and t[0] <= 2):
            slowdown_groups["GROUP 4: [0,1] [1,2] or [1,2] [0,1]"].append((tasks_pair, procs_pair, t))
            sum_group_sizes += 1
            
        if (t[0] >= 0 and t[0] <= 1 and t[1] >= 2) or \
           (t[1] >= 0 and t[1] <= 1 and t[0] >= 2):
            slowdown_groups["GROUP 5: [0,1] [2,inf] or [2,inf] [0,1]"].append((tasks_pair, procs_pair, t))
            sum_group_sizes += 1

        if (t[0] >= 1 and t[0] <= 2 and t[1] >= 2) or \
           (t[1] >= 1 and t[1] <= 2 and t[0] >= 2):
            slowdown_groups["GROUP 6: [1,2] [2,inf] or [2,inf] [1,2]"].append((tasks_pair, procs_pair, t))
            sum_group_sizes += 1
            

for name, group in slowdown_groups.items():
    print("%s, group size -> %d" % (name, len(group)))
    for member in group:
        print("\t%s" % str(member))
        
print("Summary group sizes -> %d" % sum_group_sizes)
# Out:
# DIVIDE TASKS IN SIX GROUPS
# GROUP 1: [0,1) [0,1), group size -> 0
# GROUP 2: [1,2) [1,2), group size -> 29
# 	(('is', 'cg'), (32, 4), (1.1498257839721253, 1.5121951219512195))
# 	(('is', 'cg'), (32, 8), (1.17595818815331, 1.8208092485549134))
# 	(('is', 'ft'), (32, 4), (1.5505226480836236, 1.6905615292712066))
# 	(('is', 'ep'), (32, 4), (1.6289198606271775, 1.3206997084548107))
# 	(('is', 'ep'), (32, 8), (1.6202090592334493, 1.4816810344827585))
# 	(('is', 'ep'), (32, 16), (1.1585365853658536, 1.2432915921288012))
# 	(('is', 'ep'), (32, 32), (1.1672473867595818, 1.826424870466321))
# 	(('ep', 'lu'), (4, 32), (1.7930029154518954, 1.0336496477848285))
# 	(('ep', 'lu'), (8, 32), (1.8103448275862066, 1.012982476567503))
# 	(('ep', 'lu'), (16, 32), (1.7620751341681573, 1.027536822495197))
# 	(('ep', 'lu'), (32, 4), (1.761658031088083, 1.199895433949111))
# 	(('ep', 'lu'), (32, 8), (1.6580310880829014, 1.2966297916130691))
# 	(('ep', 'lu'), (32, 16), (1.8652849740932642, 1.1609607951408063))
# 	(('ep', 'ep'), (4, 32), (1.381924198250729, 1.3471502590673574))
# 	(('ep', 'ep'), (8, 32), (1.5463362068965516, 1.6839378238341969))
# 	(('ep', 'ep'), (32, 8), (1.7098445595854923, 1.5086206896551722))
# 	(('is', 'is'), (32, 4), (1.8554006968641112, 1.1141304347826086))
# 	(('is', 'is'), (32, 8), (1.254355400696864, 1.171875))
# 	(('is', 'is'), (32, 16), (1.4459930313588847, 1.262135922330097))
# 	(('ep', 'cg'), (4, 32), (1.8192419825072887, 1.1126553302812296))
# 	(('ep', 'cg'), (8, 32), (1.8803879310344827, 1.0685088293001963))
# 	(('ep', 'cg'), (16, 32), (1.9677996422182469, 1.0178221059516024))
# 	(('ep', 'ft'), (4, 32), (1.5597667638483965, 1.796522858982614))
# 	(('ep', 'ft'), (8, 32), (1.8426724137931032, 1.4005151320025755))
# 	(('ep', 'ft'), (16, 32), (1.7978533094812161, 1.3747585318737925))
# 	(('ep', 'ft'), (32, 4), (1.5284974093264247, 1.4456391875746712))
# 	(('ft', 'ft'), (32, 4), (1.796522858982614, 1.8637992831541217))
# 	(('is', 'lu'), (32, 4), (1.6202090592334493, 1.2373649355176017))
# 	(('is', 'lu'), (32, 8), (1.8554006968641112, 1.395677900694623))
# GROUP 3: [2,inf) [2,inf), group size -> 18
# 	(('lu', 'ft'), (8, 32), (2.797787496784152, 4.195106245975531))
# 	(('lu', 'ft'), (16, 32), (2.887907233572612, 4.16613007083065))
# 	(('cg', 'lu'), (32, 8), (2.3569326357096143, 4.297658862876253))
# 	(('cg', 'lu'), (32, 16), (2.615271419228254, 5.080066261733848))
# 	(('cg', 'cg'), (32, 32), (3.527632439502943, 3.512099411379987))
# 	(('is', 'ft'), (32, 16), (2.238675958188153, 3.329355608591885))
# 	(('ep', 'ep'), (32, 16), (2.176165803108808, 2.101967799642218))
# 	(('ep', 'ep'), (32, 32), (2.681347150259067, 2.422279792746114))
# 	(('is', 'is'), (16, 32), (10.631067961165048, 2.05574912891986))
# 	(('ft', 'ft'), (4, 32), (3.028673835125448, 2.0090148100450738))
# 	(('ft', 'ft'), (8, 32), (6.507352941176472, 2.395363811976819))
# 	(('ft', 'ft'), (16, 32), (9.642004773269688, 2.6046361880231808))
# 	(('ft', 'ft'), (32, 8), (2.524146812620734, 6.525735294117648))
# 	(('ft', 'ft'), (32, 16), (2.9072762395363805, 11.479713603818613))
# 	(('ft', 'ft'), (32, 32), (6.027044430135221, 6.265292981326464))
# 	(('cg', 'ft'), (16, 32), (45.15, 4.752092723760463))
# 	(('cg', 'ft'), (32, 32), (2.142740353172008, 5.9079201545396005))
# 	(('lu', 'lu'), (32, 32), (2.9792746113989637, 3.015078302381091))
# GROUP 4: [0,1] [1,2] or [1,2] [0,1], group size -> 0
# GROUP 5: [0,1] [2,inf] or [2,inf] [0,1], group size -> 3
# 	(('is', 'cg'), (8, 32), (10.2734375, 0.972858077174624))
# 	(('cg', 'cg'), (4, 32), (4.317073170731708, 0.9278940483976456))
# 	(('ep', 'cg'), (32, 32), (2.227979274611399, 0.9892086330935252))
# GROUP 6: [1,2] [2,inf] or [2,inf] [1,2], group size -> 55
# 	(('lu', 'ft'), (4, 32), (1.8996165911467409, 3.54475209272376))
# 	(('lu', 'ft'), (32, 4), (1.0892472492286198, 2.6344086021505375))
# 	(('lu', 'ft'), (32, 8), (1.1230133317808697, 5.220588235294118))
# 	(('lu', 'ft'), (32, 16), (1.180648541654538, 11.897374701670644))
# 	(('lu', 'ft'), (32, 32), (1.4929848052628516, 5.9079201545396005))
# 	(('is', 'cg'), (4, 32), (8.777173913043478, 1.0178221059516024))
# 	(('is', 'cg'), (16, 32), (16.74757281553398, 1.0668737737083063))
# 	(('is', 'cg'), (32, 16), (1.5940766550522647, 5.125))
# 	(('is', 'cg'), (32, 32), (2.9529616724738674, 1.1371811641595815))
# 	(('cg', 'lu'), (4, 32), (5.926829268292684, 1.0319031262735054))
# 	(('cg', 'lu'), (8, 32), (22.572254335260116, 1.0985620306223438))
# 	(('cg', 'lu'), (16, 32), (43.625, 1.2572044012342085))
# 	(('cg', 'lu'), (32, 4), (1.9408109875735775, 2.628964796096201))
# 	(('cg', 'lu'), (32, 32), (3.5595160235448007, 1.907492577283577))
# 	(('cg', 'cg'), (8, 32), (17.774566473988443, 1.130640941792021))
# 	(('cg', 'cg'), (16, 32), (48.325, 1.8173642903858733))
# 	(('cg', 'cg'), (32, 4), (1.014551994767822, 4.7560975609756095))
# 	(('cg', 'cg'), (32, 8), (1.1298234139960759, 12.832369942196534))
# 	(('cg', 'cg'), (32, 16), (1.815729234793983, 45.900000000000006))
# 	(('is', 'ft'), (4, 32), (6.684782608695652, 1.648422408242112))
# 	(('is', 'ft'), (8, 32), (8.1640625, 1.233097231165486))
# 	(('is', 'ft'), (16, 32), (4.3203883495145625, 1.3747585318737925))
# 	(('is', 'ft'), (32, 8), (1.7944250871080138, 2.950367647058824))
# 	(('is', 'ft'), (32, 32), (2.822299651567944, 1.7482292337411458))
# 	(('is', 'ep'), (4, 32), (4.320652173913044, 1.4766839378238341))
# 	(('is', 'ep'), (8, 32), (4.921875, 1.515544041450777))
# 	(('is', 'ep'), (16, 32), (4.854368932038835, 1.994818652849741))
# 	(('ep', 'lu'), (32, 32), (2.810880829015544, 1.0391802992373524))
# 	(('ep', 'ep'), (16, 32), (1.8694096601073342, 2.0595854922279795))
# 	(('ep', 'ep'), (32, 4), (2.176165803108808, 1.3352769679300294))
# 	(('is', 'is'), (4, 32), (4.891304347826087, 1.3937282229965156))
# 	(('is', 'is'), (8, 32), (8.3203125, 1.6724738675958186))
# 	(('is', 'is'), (32, 32), (1.7421602787456445, 2.160278745644599))
# 	(('ep', 'cg'), (32, 4), (1.3082901554404145, 2.902439024390244))
# 	(('ep', 'cg'), (32, 8), (1.645077720207254, 5.780346820809249))
# 	(('ep', 'cg'), (32, 16), (1.9041450777202071, 5.7))
# 	(('ep', 'ft'), (32, 8), (1.6839378238341969, 2.1415441176470593))
# 	(('ep', 'ft'), (32, 16), (1.9300518134715026, 2.995226730310262))
# 	(('ep', 'ft'), (32, 32), (2.3575129533678756, 1.5132002575660013))
# 	(('is', 'lu'), (4, 32), (2.5, 1.0074518251149793))
# 	(('is', 'lu'), (8, 32), (10.625, 1.0403446469115678))
# 	(('is', 'lu'), (16, 32), (6.74757281553398, 1.0342318216219364))
# 	(('is', 'lu'), (32, 16), (2.1341463414634148, 1.3362782992821645))
# 	(('is', 'lu'), (32, 32), (2.822299651567944, 1.0546079059207079))
# 	(('cg', 'ft'), (4, 32), (5.463414634146342, 1.3618802318094012))
# 	(('cg', 'ft'), (8, 32), (11.647398843930638, 1.4745653573728266))
# 	(('cg', 'ft'), (32, 4), (1.198495748855461, 3.6977299880525685))
# 	(('cg', 'ft'), (32, 8), (1.1780575539568345, 5.294117647058824))
# 	(('cg', 'ft'), (32, 16), (1.2638979725310662, 10.704057279236277))
# 	(('lu', 'lu'), (4, 32), (2.8415824329034503, 1.3017406997729521))
# 	(('lu', 'lu'), (8, 32), (5.870851556470285, 1.4926937183442976))
# 	(('lu', 'lu'), (16, 32), (6.887078961899503, 1.7022762997030914))
# 	(('lu', 'lu'), (32, 4), (1.296792222157536, 2.875566399442314))
# 	(('lu', 'lu'), (32, 8), (1.4426267683530303, 5.701054798044764))
# 	(('lu', 'lu'), (32, 16), (1.7115910810968156, 6.876035339591387))
# Summary group sizes -> 105

# %%
# Draw slowdown info
# Relative slowdown
# Calculate for each pair in experiments -> max(t1_sharing, t2_sharing) / (t1_pure + t2_pure)

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
# %matplotlib inline


tasks = ["is", "ep", "cg", "lu", "ft"]
colors = {"is": "red", "ep": "blue", "cg": "orange", "lu": "black", "ft": "cyan"}
markers = {"is": ".", "ep": "_", "cg": "+", "lu": "x", "ft": "."}

# Figure configuration
fig = plt.figure(figsize=(12,30), dpi=300)
ax = fig.add_subplot(111)
plt.title('NPB MPI tasks relative slowdown two parallel tasks and two serial tasks execution (size A)', fontsize=16)

# Draw
# X_DOTS = [2, 5, 6, 7, 8] # index int list [(4,4), (4,8), ..., (16,16)]
X_DOTS = [3, 7, 11, 12, 13, 14, 15] # NOTE! For 32 threads only

green = 0
red = 0

for tasks_pair, procs in results_sharing.items():
    n = -1
    for procs_pair, t in procs.items():
        n += 1
        if (n not in X_DOTS):
            continue
        
        t1_p = results_pure[tasks_pair[0]]["A"][procs_pair[0]]
        t2_p = results_pure[tasks_pair[1]]["A"][procs_pair[1]]

        task1 = tasks_pair[0]
        task2 = tasks_pair[1]
        
        # TODO
        # remove double dots
        rel_sl1 = max(t[0], t[1]) / (t1_p + t2_p)
        rel_sl2 = max(t[0], t[1]) / (t1_p + t2_p)
        
        color = "black"
        if rel_sl1 < 1 and rel_sl2 < 1:
            color = "green"
            green += 1
        else:
            color = "red"
            red += 1
            
        ax.plot(X_DOTS.index(n), rel_sl1, color=color, marker=markers[task1])
        ax.plot(X_DOTS.index(n), rel_sl2, color=color, marker=markers[task2])

# Draw slowdown lines with factor 1 and 2
PROCS_PAIR = list(results_sharing[('is', 'is')].keys())
null_slowdown_x = np.linspace(0, len(X_DOTS)-1, num=2)
null_slowdown_y = np.zeros(2)
ax.plot(null_slowdown_x, null_slowdown_y+1, color="red", linestyle=":")

ax.plot(null_slowdown_x, null_slowdown_y+2, color="red", linestyle=":")

# Axes configuration
ax.set_xticks(np.arange(len(X_DOTS)))
ax.set_xticklabels([PROCS_PAIR[i] for i in X_DOTS])
ax.set_xlabel("(np1, np2)")
ax.set_ylabel("Slowdown (share / pure) [seconds]")


# Grid configuration
stepsize = 0.2
start, end = ax.get_ylim()
ax.yaxis.set_ticks(np.arange(0, end, stepsize))

ax.set_axisbelow(True)
ax.grid(which='both')
ax.grid(which='major', alpha=0.5)

# Form legend
legend_elements = []
for task in tasks:
    legend_elements.append(
        Line2D([], [], marker=markers[task], color="black", linestyle='None', label=task, markersize=10))

legend_elements.append(
        Line2D([0], [0], color="green", linestyle='-', label="Relative slowdown less 1, %d pairs" % green))
legend_elements.append(
        Line2D([0], [0], color="red", linestyle='-', label="Relative slowdown more 1, %d pairs" % red))

# Show figure
ax.legend(handles=legend_elements)
plt.tight_layout()
plt.show()
fig.savefig('./relative_slowdown_size_A_groups_%s.png' % str('_'.join(map(str, X_DOTS))), fmt='png')
plt.close(fig)
# plt.gcf().clear()
